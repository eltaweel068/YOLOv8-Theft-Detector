# %% [markdown]
# <a href="https://colab.research.google.com/github/eltaweel068/YOLOv8-Theft-Detector/blob/main/Glass_break.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow ultralytics

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="mvHmXwWHB7dq5f2A5SRb")
project = rf.workspace("workspace-bdrph").project("theft-detection-gge4g")
version = project.version(9)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo train data='Theft-Detection-9/data.yaml' model=yolov8n.pt epochs=50 imgsz=640
# Out:
# ...
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls Theft-Detection-9/test/images
# Out:
# 102_jpeg_jpg.rf.0cea3d555babe69134c472faa3831b34.jpg
# 111_jpeg_jpg.rf.b35c9ebbccc8d6d05d1e569dbf0bcd8a.jpg
# 114_jpeg_jpg.rf.88aa52ee745905bbe5a57faf65b20a1d.jpg
# 116_jpeg_jpg.rf.bb9ccff79fc52d79a2777ca28ee74eb2.jpg
# 11_jpg.rf.d0d7c997500bf0dc5b15c3148e3e5c03.jpg
# 13_jpg.rf.922913d46a0f4215b3af9ed21abfb48e.jpg
# 144_mp4-31_jpg.rf.21490fda3fff23686aeb857e8dd9cad3.jpg
# 144_mp4-44_jpg.rf.0470071a7ba0812de928df2d0f0a3ad6.jpg
# 144_mp4-45_jpg.rf.3a1345cf2c72848fba39fc94f2741b90.jpg
# 144_mp4-51_jpg.rf.ec62109869eaea638f02eee38578ac8a.jpg
# 144_mp4-57_jpg.rf.578111be0ebf8d0e0cac8bb1826d2f98.jpg
# 28_jpg.rf.6d2ea427bc0efa7ce7be6d9fd9d2eb8e.jpg
# 38_jpg.rf.3cc8c924d128817078a3827774fca128.jpg
# 43_jpg.rf.3ed86d7f951bd631efda52c0b6b87f2e.jpg
# 44_jpg.rf.e00d968a48ce695e0c76887169362cf7.jpg
# 46_jpg.rf.6be1cebf75920bb85559bd9e9707832d.jpg
# 53_jpeg_jpg.rf.e3df304f6307c162f26703a28f62a845.jpg
# 68_jpeg_jpg.rf.d6e94706f693712d8dc9e0ee62858fae.jpg
# ...

# %%
# !ls
# Out:
# drive  sample_data	test_video.mkv	Theft-Detection-9  yolov8n.pt
# runs   test_video2.mp4	test_video.mp4	yolo11n.pt

# %%
# !yolo predict model='/content/runs/detect/train/weights/best.pt' source='Theft-Detection-9/test/images/DefenseKnifeAttack0842_jpg.rf.3b60d34379255305d1d04bf2f95abad7.jpg'
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/Theft-Detection-9/test/images/DefenseKnifeAttack0842_jpg.rf.3b60d34379255305d1d04bf2f95abad7.jpg: 640x640 1 knife, 13.1ms
# Speed: 5.8ms preprocess, 13.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !ls -l runs/detect/predict
# Out:
# total 60
# -rw-r--r-- 1 root root 58332 Nov  7 10:26 DefenseKnifeAttack0842_jpg.rf.3b60d34379255305d1d04bf2f95abad7.jpg

# %%
from IPython.display import Image
Image(filename='runs/detect/predict/DefenseKnifeAttack0842_jpg.rf.3b60d34379255305d1d04bf2f95abad7.jpg')

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/

# %%
# !pip install ultralytics

# %%
# !yolo val model='/content/runs/detect/train/weights/best.pt' data='Theft-Detection-9/data.yaml' split='test'
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1088.5±264.1 MB/s, size: 41.1 KB)
# val: Scanning /content/Theft-Detection-9/test/labels.cache... 266 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 266/266 2.8Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 74, len(boxes) = 365. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 17/17 4.9it/s 3.5s
#                    all        266        365      0.757      0.699      0.758      0.541
#                   card          2          2      0.536        0.5      0.523      0.317
# ...

# %%
# !pip install yt-dlp

# %%
# !yt-dlp -o 'test_video' 'https://youtu.be/HrZX9vDtyFc?si=IlJAZtV3wnvVDkZg'
# Out:
# [youtube] Extracting URL: https://youtu.be/HrZX9vDtyFc?si=IlJAZtV3wnvVDkZg
# [youtube] HrZX9vDtyFc: Downloading webpage
# [youtube] HrZX9vDtyFc: Downloading android sdkless player API JSON
# [youtube] HrZX9vDtyFc: Downloading tv client config
# [youtube] HrZX9vDtyFc: Downloading tv player API JSON
# [youtube] HrZX9vDtyFc: Downloading web safari player API JSON
# [youtube] HrZX9vDtyFc: Downloading player 65578ad1-main
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/65578ad1/player_ias.vflset/en_US/base.js
# WARNING: [youtube] HrZX9vDtyFc: nsig extraction failed: Some formats may be missing
#          n = DrvJohOf5L2CvRB ; player = https://www.youtube.com/s/player/65578ad1/player_ias.vflset/en_US/base.js
#          Please report this issue on  https://github.com/yt-dlp/yt-dlp/issues?q= , filling out the appropriate issue template. Confirm you are on the latest version using  yt-dlp -U
# ...

# %%
# !yolo predict model='/content/runs/detect/train/weights/best.pt' source='test_video.mp4' conf=0.5
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/1109) /content/test_video.mp4: 480x640 (no detections), 44.1ms
# video 1/1 (frame 2/1109) /content/test_video.mp4: 480x640 1 money, 5.9ms
# video 1/1 (frame 3/1109) /content/test_video.mp4: 480x640 (no detections), 6.1ms
# video 1/1 (frame 4/1109) /content/test_video.mp4: 480x640 (no detections), 5.9ms
# video 1/1 (frame 5/1109) /content/test_video.mp4: 480x640 1 money, 5.9ms
# video 1/1 (frame 6/1109) /content/test_video.mp4: 480x640 (no detections), 5.9ms
# video 1/1 (frame 7/1109) /content/test_video.mp4: 480x640 (no detections), 7.6ms
# video 1/1 (frame 8/1109) /content/test_video.mp4: 480x640 (no detections), 5.9ms
# video 1/1 (frame 9/1109) /content/test_video.mp4: 480x640 (no detections), 5.9ms
# video 1/1 (frame 10/1109) /content/test_video.mp4: 480x640 1 knife, 5.9ms
# ...

# %%
# !yt-dlp -o 'test_video2' 'https://youtu.be/FFP8LKIfZqw?si=VUNnbvePXiJhQ7kY'
# Out:
# [youtube] Extracting URL: https://youtu.be/FFP8LKIfZqw?si=VUNnbvePXiJhQ7kY
# [youtube] FFP8LKIfZqw: Downloading webpage
# [youtube] FFP8LKIfZqw: Downloading android sdkless player API JSON
# [youtube] FFP8LKIfZqw: Downloading tv client config
# [youtube] FFP8LKIfZqw: Downloading tv player API JSON
# [youtube] FFP8LKIfZqw: Downloading web safari player API JSON
# [youtube] FFP8LKIfZqw: Downloading player 65578ad1-main
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/65578ad1/player_ias.vflset/en_US/base.js
# WARNING: [youtube] FFP8LKIfZqw: nsig extraction failed: Some formats may be missing
#          n = i17SI3Pf7t5qkz0 ; player = https://www.youtube.com/s/player/65578ad1/player_ias.vflset/en_US/base.js
#          Please report this issue on  https://github.com/yt-dlp/yt-dlp/issues?q= , filling out the appropriate issue template. Confirm you are on the latest version using  yt-dlp -U
# ...

# %%
# !yolo predict model='/content/runs/detect/train/weights/best.pt' source='test_video2.mp4'
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/1109) /content/test_video2.mp4: 480x640 (no detections), 44.8ms
# video 1/1 (frame 2/1109) /content/test_video2.mp4: 480x640 1 money, 6.0ms
# video 1/1 (frame 3/1109) /content/test_video2.mp4: 480x640 1 money, 6.3ms
# video 1/1 (frame 4/1109) /content/test_video2.mp4: 480x640 1 money, 5.9ms
# video 1/1 (frame 5/1109) /content/test_video2.mp4: 480x640 1 money, 5.9ms
# video 1/1 (frame 6/1109) /content/test_video2.mp4: 480x640 (no detections), 5.9ms
# video 1/1 (frame 7/1109) /content/test_video2.mp4: 480x640 (no detections), 5.9ms
# video 1/1 (frame 8/1109) /content/test_video2.mp4: 480x640 (no detections), 5.9ms
# video 1/1 (frame 9/1109) /content/test_video2.mp4: 480x640 (no detections), 6.0ms
# video 1/1 (frame 10/1109) /content/test_video2.mp4: 480x640 1 knife, 5.9ms
# ...

# %%
from IPython.display import Video
Video("test_video.mp4")
# Out:
# <video src="test_video.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# !yolo predict model='/content/runs/detect/train/weights/best.pt' source='/content/1000_F_142157000_vJ3MAGeYm4aeVlyOvFxcDJ3c31JdP6UA.jpg' conf=0.5
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/1000_F_142157000_vJ3MAGeYm4aeVlyOvFxcDJ3c31JdP6UA.jpg: 448x640 1 knife, 44.4ms
# Speed: 3.6ms preprocess, 44.4ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict9
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model='/content/runs/detect/train/weights/best.pt' source='/content/dangerous-man-dressed-in-black-with-a-balaclava-on-his-head-preparing-breaking-with-crowbar-the-glass-of-car-before-the-stealing-car-thief-car-theft-concept-free-photo.jpeg' conf=0.5
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,007,988 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/dangerous-man-dressed-in-black-with-a-balaclava-on-his-head-preparing-breaking-with-crowbar-the-glass-of-car-before-the-stealing-car-thief-car-theft-concept-free-photo.jpeg: 448x640 1 crowbar, 41.7ms
# Speed: 3.4ms preprocess, 41.7ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict16
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/predict9/1000_F_142157000_vJ3MAGeYm4aeVlyOvFxcDJ3c31JdP6UA.jpg')

# %%
from IPython.display import Image
Image(filename='/content/dangerous-man-dressed-in-black-with-a-balaclava-on-his-head-preparing-breaking-with-crowbar-the-glass-of-car-before-the-stealing-car-thief-car-theft-concept-free-photo.jpeg')
